# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q transformers datasets accelerate evaluate wandb
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 126.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 41.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 52.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 26.2.1 requires cuda-toolkit[nvcc,nvrtc]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.

# %%
# !pip install -U torchvision
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.26.0+cu128)
# Collecting torchvision
#   Downloading torchvision-0.27.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Collecting torch==2.12.0 (from torchvision)
#   Downloading torch-2.12.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.12.0->torchvision) (3.29.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.12.0->torchvision) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch==2.12.0->torchvision) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.12.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.12.0->torchvision) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.12.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.12.0->torchvision) (2025.3.0)
# Collecting cuda-toolkit==13.0.2 (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.12.0->torchvision)
#   Downloading cuda_toolkit-13.0.2-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting nvidia-cublas<=13.1.1.3,>=13.1.0.3 (from torch==2.12.0->torchvision)
#   Downloading nvidia_cublas-13.1.1.3-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting cuda-bindings<14,>=13.0.3 (from torch==2.12.0->torchvision)
#   Downloading cuda_bindings-13.3.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.5 kB)
# Collecting nvidia-cudnn-cu13==9.20.0.48 (from torch==2.12.0->torchvision)
#   Downloading nvidia_cudnn_cu13-9.20.0.48-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Collecting nvidia-cusparselt-cu13==0.8.1 (from torch==2.12.0->torchvision)
#   Downloading nvidia_cusparselt_cu13-0.8.1-py3-none-manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting nvidia-nccl-cu13==2.29.7 (from torch==2.12.0->torchvision)
#   Downloading nvidia_nccl_cu13-2.29.7-py3-none-manylinux_2_18_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvshmem-cu13==3.4.5 (from torch==2.12.0->torchvision)
#   Downloading nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting triton==3.7.0 (from torch==2.12.0->torchvision)
#   Downloading triton-3.7.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime==13.0.96.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.12.0->torchvision)
#   Downloading nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft==12.0.0.61.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.12.0->torchvision)
#   Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cufile==1.15.1.6.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.12.0->torchvision)
#   Downloading nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti==13.0.85.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.12.0->torchvision)
#   Downloading nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand==10.4.0.35.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.12.0->torchvision)
#   Downloading nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver==12.0.4.66.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.12.0->torchvision)
#   Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse==12.6.3.3.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.12.0->torchvision)
#   Downloading nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink==13.0.88.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.12.0->torchvision)
#   Downloading nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-nvrtc==13.0.88.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.12.0->torchvision)
#   Downloading nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvtx==13.0.85.* (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch==2.12.0->torchvision)
#   Downloading nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<14,>=13.0.3->torch==2.12.0->torchvision) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.12.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.12.0->torchvision) (3.0.3)
# Downloading torchvision-0.27.0-cp312-cp312-manylinux_2_28_x86_64.whl (7.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 158.5 MB/s eta 0:00:00
# Downloading torch-2.12.0-cp312-cp312-manylinux_2_28_x86_64.whl (532.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.3/532.3 MB 2.6 MB/s eta 0:00:00
# Downloading cuda_toolkit-13.0.2-py2.py3-none-any.whl (2.4 kB)
# Downloading nvidia_cudnn_cu13-9.20.0.48-py3-none-manylinux_2_27_x86_64.whl (366.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.2/366.2 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu13-0.8.1-py3-none-manylinux2014_x86_64.whl (170.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.1/170.1 MB 15.4 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu13-2.29.7-py3-none-manylinux_2_18_x86_64.whl (206.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.0/206.0 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (60.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 43.7 MB/s eta 0:00:00
# Downloading triton-3.7.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (201.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.5/201.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 150.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (90.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 MB 29.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 108.0 MB/s eta 0:00:00
# Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (214.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 79.8 MB/s eta 0:00:00
# Downloading nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl (59.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 MB 43.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl (200.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (145.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (40.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 MB 67.4 MB/s eta 0:00:00
# Downloading nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 17.0 MB/s eta 0:00:00
# Downloading cuda_bindings-13.3.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 136.1 MB/s eta 0:00:00
# Downloading nvidia_cublas-13.1.1.3-py3-none-manylinux_2_27_x86_64.whl (423.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 2.6 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu13, cuda-toolkit, triton, nvidia-nvtx, nvidia-nvshmem-cu13, nvidia-nvjitlink, nvidia-nccl-cu13, nvidia-curand, nvidia-cufile, nvidia-cuda-runtime, nvidia-cuda-nvrtc, nvidia-cuda-cupti, cuda-bindings, nvidia-cusparse, nvidia-cufft, nvidia-cublas, nvidia-cusolver, nvidia-cudnn-cu13, torch, torchvision
#   Attempting uninstall: cuda-toolkit
#     Found existing installation: cuda-toolkit 12.8.1
#     Uninstalling cuda-toolkit-12.8.1:
#       Successfully uninstalled cuda-toolkit-12.8.1
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: cuda-bindings
#     Found existing installation: cuda-bindings 12.9.7
#     Uninstalling cuda-bindings-12.9.7:
#       Successfully uninstalled cuda-bindings-12.9.7
#   Attempting uninstall: torch
#     Found existing installation: torch 2.11.0+cu128
#     Uninstalling torch-2.11.0+cu128:
#       Successfully uninstalled torch-2.11.0+cu128
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.26.0+cu128
#     Uninstalling torchvision-0.26.0+cu128:
#       Successfully uninstalled torchvision-0.26.0+cu128
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcuvs-cu12 26.2.0 requires cuda-toolkit[cublas,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# cuda-python 12.9.7 requires cuda-bindings~=12.9.7, but you have cuda-bindings 13.3.1 which is incompatible.
# libcuml-cu12 26.2.0 requires cuda-toolkit[cublas,cufft,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# libraft-cu12 26.2.0 requires cuda-toolkit[cublas,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# cuml-cu12 26.2.0 requires cuda-toolkit[cublas,cufft,curand,cusolver,cusparse]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# cudf-cu12 26.2.1 requires cuda-toolkit[nvcc,nvrtc]==12.*, but you have cuda-toolkit 13.0.2 which is incompatible.
# Successfully installed cuda-bindings-13.3.1 cuda-toolkit-13.0.2 nvidia-cublas-13.1.1.3 nvidia-cuda-cupti-13.0.85 nvidia-cuda-nvrtc-13.0.88 nvidia-cuda-runtime-13.0.96 nvidia-cudnn-cu13-9.20.0.48 nvidia-cufft-12.0.0.61 nvidia-cufile-1.15.1.6 nvidia-curand-10.4.0.35 nvidia-cusolver-12.0.4.66 nvidia-cusparse-12.6.3.3 nvidia-cusparselt-cu13-0.8.1 nvidia-nccl-cu13-2.29.7 nvidia-nvjitlink-13.0.88 nvidia-nvshmem-cu13-3.4.5 nvidia-nvtx-13.0.85 torch-2.12.0 torchvision-0.27.0 triton-3.7.0

# %%
# !pip uninstall -y transformers datasets torchvision
# !pip install -q \
transformers==4.52.4 \
datasets==3.6.0 \
accelerate==1.7.0 \
evaluate==0.4.3 \
wandb
# Out:
# Found existing installation: transformers 5.12.1
# Uninstalling transformers-5.12.1:
#   Successfully uninstalled transformers-5.12.1
# Found existing installation: datasets 5.0.0
# Uninstalling datasets-5.0.0:
#   Successfully uninstalled datasets-5.0.0
# WARNING: Skipping torchvision as it is not installed.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 154.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 43.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.1/362.1 kB 33.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 49.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 124.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# timm 1.0.27 requires torchvision, which is not installed.

# %%
import pandas as pd
import numpy as np
import torch
from datasets import Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer
)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
import evaluate
import wandb

# %%
wandb.login()

wandb.init(
    project="23f1000054-t22026",
    name="deberta_v3_base_v1"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter: ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/content/wandb/run-20260617_045606-hvszvlqu</code>
# Syncing run <strong><a href='https://wandb.ai/23f1000054-dl-genai-project/23f1000054-t22026/runs/hvszvlqu' target="_blank">deberta_v3_base_v1</a></strong> to <a href='https://wandb.ai/23f1000054-dl-genai-project/23f1000054-t22026' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/23f1000054-dl-genai-project/23f1000054-t22026' target="_blank">https://wandb.ai/23f1000054-dl-genai-project/23f1000054-t22026</a>
#  View run at <a href='https://wandb.ai/23f1000054-dl-genai-project/23f1000054-t22026/runs/hvszvlqu' target="_blank">https://wandb.ai/23f1000054-dl-genai-project/23f1000054-t22026/runs/hvszvlqu</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/23f1000054-dl-genai-project/23f1000054-t22026/runs/hvszvlqu?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
train = pd.read_csv(
    "/content/drive/MyDrive/SmartMCQ/train.csv"
)

test = pd.read_csv(
    "/content/drive/MyDrive/SmartMCQ/test.csv"
)

print(train.shape)
print(test.shape)
# Out:
# (2000, 8)
# (500, 7)

# %%
rows = []

for _, row in train.iterrows():

    prompt = row["prompt"]
    answer = row["answer"]

    for option in ["A","B","C","D","E"]:

        rows.append({
            "text": prompt,
            "option": str(row[option]),
            "label": int(option == answer)
        })

binary_train = pd.DataFrame(rows)

print(binary_train.shape)
binary_train.head()
# Out:
# (10000, 3)
#                                                 text  \
# 0  Pick the best possible answer: What is Martin ...
# 1  Pick the best possible answer: What is Martin ...
# 2  Pick the best possible answer: What is Martin ...
# 3  Pick the best possible answer: What is Martin ...
# 4  Pick the best possible answer: What is Martin ...
#
#                                               option  label
# 0  Martin Heidegger believes that humans exist wi...      0
# 1  Martin Heidegger believes that humans do not e...      1
# 2  Martin Heidegger does not believe in the exist...      0
# 3  Martin Heidegger believes that the relationshi...      0
# 4  Martin Heidegger believes that time is an illu...      0

# %%
train_df, valid_df = train_test_split(
    binary_train,
    test_size=0.2,
    random_state=42,
    stratify=binary_train["label"]
)

print(train_df.shape)
print(valid_df.shape)
# Out:
# (8000, 3)
# (2000, 3)

# %%
train_ds = Dataset.from_pandas(
    train_df.reset_index(drop=True)
)

valid_ds = Dataset.from_pandas(
    valid_df.reset_index(drop=True)
)

# %%
MODEL_NAME = "microsoft/deberta-v3-base"

tokenizer = AutoTokenizer.from_pretrained(
    MODEL_NAME
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/convert_slow_tokenizer.py:564: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
def tokenize(batch):

    return tokenizer(
        batch["text"],
        batch["option"],
        truncation=True,
        padding="max_length",
        max_length=256
    )

train_ds = train_ds.map(
    tokenize,
    batched=True
)

valid_ds = valid_ds.map(
    tokenize,
    batched=True
)
# Out:
# Map:   0%|          | 0/8000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
train_ds = train_ds.remove_columns(
    ["text","option"]
)

valid_ds = valid_ds.remove_columns(
    ["text","option"]
)

train_ds.set_format("torch")
valid_ds.set_format("torch")

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    MODEL_NAME,
    num_labels=2
)
# Out:
# pytorch_model.bin:   0%|          | 0.00/371M [00:00<?, ?B/s]
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-v3-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(
        logits,
        axis=1
    )
    acc = accuracy_score(
        labels,
        preds
    )
    f1 = f1_score(
        labels,
        preds
    )
    return {
        "accuracy": acc,
        "f1": f1
    }

# %%
training_args = TrainingArguments(
    output_dir="./results",
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="epoch",
    learning_rate=1e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    gradient_accumulation_steps=2,
    num_train_epochs=5,
    weight_decay=0.01,
    warmup_ratio=0.1,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    greater_is_better=True,
    save_total_limit=2,
    report_to="wandb"
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=valid_ds,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
#     <div>
#
#       <progress value='1250' max='1250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1250/1250 22:45, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.523300</td>
#       <td>0.495480</td>
#       <td>0.800000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.423900</td>
#       <td>0.346452</td>
#       <td>0.858500</td>
#       <td>0.499115</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.232400</td>
#       <td>0.176001</td>
#       <td>0.935000</td>
#       <td>0.812139</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.130800</td>
#       <td>0.098369</td>
#       <td>0.970000</td>
#       <td>0.920844</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.092000</td>
#       <td>0.100701</td>
#       <td>0.969000</td>
#       <td>0.916216</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1250, training_loss=0.2804610412597656, metrics={'train_runtime': 1366.5781, 'train_samples_per_second': 29.27, 'train_steps_per_second': 0.915, 'total_flos': 5262315479040000.0, 'train_loss': 0.2804610412597656, 'epoch': 5.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='125' max='125' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [125/125 00:21]
#     </div>
# {'eval_loss': 0.09836888313293457,
#  'eval_accuracy': 0.97,
#  'eval_f1': 0.920844327176781,
#  'eval_runtime': 21.4246,
#  'eval_samples_per_second': 93.351,
#  'eval_steps_per_second': 5.834,
#  'epoch': 5.0}

# %%
trainer.save_model(
    "/content/drive/MyDrive/SmartMCQ/deberta_v3_base"
)

tokenizer.save_pretrained(
    "/content/drive/MyDrive/SmartMCQ/deberta_v3_base"
)
# Out:
# ('/content/drive/MyDrive/SmartMCQ/deberta_v3_base/tokenizer_config.json',
#  '/content/drive/MyDrive/SmartMCQ/deberta_v3_base/special_tokens_map.json',
#  '/content/drive/MyDrive/SmartMCQ/deberta_v3_base/spm.model',
#  '/content/drive/MyDrive/SmartMCQ/deberta_v3_base/added_tokens.json',
#  '/content/drive/MyDrive/SmartMCQ/deberta_v3_base/tokenizer.json')

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>▁▃▇███</td></tr><tr><td>eval/f1</td><td>▁▅▇███</td></tr><tr><td>eval/loss</td><td>█▅▂▁▁▁</td></tr><tr><td>eval/runtime</td><td>▁█▇▇▃▃</td></tr><tr><td>eval/samples_per_second</td><td>█▁▂▂▆▆</td></tr><tr><td>eval/steps_per_second</td><td>█▁▂▂▆▆</td></tr><tr><td>train/epoch</td><td>▁▁▃▃▅▅▆▆████</td></tr><tr><td>train/global_step</td><td>▁▁▃▃▅▅▆▆████</td></tr><tr><td>train/grad_norm</td><td>▁▄▄▂█</td></tr><tr><td>train/learning_rate</td><td>█▆▅▃▁</td></tr><tr><td>+1</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/accuracy</td><td>0.97</td></tr><tr><td>eval/f1</td><td>0.92084</td></tr><tr><td>eval/loss</td><td>0.09837</td></tr><tr><td>eval/runtime</td><td>21.4246</td></tr><tr><td>eval/samples_per_second</td><td>93.351</td></tr><tr><td>eval/steps_per_second</td><td>5.834</td></tr><tr><td>total_flos</td><td>5262315479040000.0</td></tr><tr><td>train/epoch</td><td>5</td></tr><tr><td>train/global_step</td><td>1250</td></tr><tr><td>train/grad_norm</td><td>13.38804</td></tr><tr><td>+6</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">deberta_v3_base_v1</strong> at: <a href='https://wandb.ai/23f1000054-dl-genai-project/23f1000054-t22026/runs/hvszvlqu' target="_blank">https://wandb.ai/23f1000054-dl-genai-project/23f1000054-t22026/runs/hvszvlqu</a><br> View project at: <a href='https://wandb.ai/23f1000054-dl-genai-project/23f1000054-t22026' target="_blank">https://wandb.ai/23f1000054-dl-genai-project/23f1000054-t22026</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260617_045606-hvszvlqu/logs</code>
